# %% [markdown]
# # AWS Bedrock Claude Sonnet & Haiku 4.5 Test
#
# Testing Claude Sonnet 4.5 and Haiku 4.5 via AWS Bedrock API.

# %%
# %pip install boto3 requests python-dotenv

import boto3
import json
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# Collecting boto3
#   Downloading boto3-1.40.69-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.1.1)
# Collecting botocore<1.41.0,>=1.40.69 (from boto3)
#   Downloading botocore-1.40.69-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/kc/Library/Python/3.13/lib/python/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /Users/kc/Library/Python/3.13/lib/python/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2025.8.3)
# Downloading boto3-1.40.69-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.69-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 13.9 MB/s  0:00:01 eta 0:00:01
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [boto3]32m3/4 [boto3]re]
# Successfully installed boto3-1.40.69 botocore-1.40.69 jmespath-1.0.1 s3transfer-0.14.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# True

# %%
# AWS Configuration - Using Bearer Token Only
aws_bearer_token = os.getenv("AWS_BEARER_TOKEN_BEDROCK") or os.getenv("AWS_BEARER_TOKEN")
aws_region = os.getenv("AWS_REGION", "us-east-1")

# Model IDs for Bedrock - Claude 4.5
sonnet_model_id = "us.anthropic.claude-sonnet-4-5-20250929-v1:0"
haiku_model_id = "us.anthropic.claude-haiku-4-5-20251001-v1:0"

if not aws_bearer_token:
    print("❌ AWS Bearer Token not found in environment")
    print("\nPlease export:")
    print("export AWS_BEARER_TOKEN_BEDROCK=your_token_here")
    print("OR")
    print("export AWS_BEARER_TOKEN=your_token_here")
else:
    print(f"✅ AWS Bearer Token found")
    print(f"Region: {aws_region}")
    print(f"Sonnet Model: {sonnet_model_id}")
    print(f"Haiku Model: {haiku_model_id}")
# Out:
# ✅ AWS Bearer Token found
# Region: us-west-2
# Sonnet Model: us.anthropic.claude-sonnet-4-5-20250929-v1:0
# Haiku Model: us.anthropic.claude-haiku-4-5-20251001-v1:0

# %%
# Using requests library with bearer token for Bedrock API
import requests

# Bedrock converse API endpoint
bedrock_endpoint = f"https://bedrock-runtime.{aws_region}.amazonaws.com"

if aws_bearer_token:
    print("✅ Ready to use Bedrock API with bearer token")
else:
    print("⚠️  Bearer token not found")
# Out:
# ✅ Ready to use Bedrock API with bearer token

# %%
# Helper function to call Bedrock converse API with bearer token
def call_bedrock_converse(model_id, prompt, max_tokens=300, temperature=0.7):
    """Call Bedrock converse API using bearer token authentication."""
    if not aws_bearer_token:
        return None, "Bearer token not found"
    
    url = f"{bedrock_endpoint}/model/{model_id}/converse"
    
    headers = {
        "Authorization": f"Bearer {aws_bearer_token}",
        "Content-Type": "application/json"
    }
    
    payload = {
        "messages": [
            {
                "role": "user",
                "content": [{"text": prompt}]
            }
        ],
        "inferenceConfig": {
            "maxTokens": max_tokens,
            "temperature": temperature
        }
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()
        return response.json(), None
    except Exception as e:
        return None, str(e)

print("✅ Helper function ready")
# Out:
# ✅ Helper function ready

# %%
# Test Claude Sonnet 4.5
sonnet_prompt = "Say 'Claude Sonnet 4.5 is working!' and explain what you're best at."

print("Testing Claude Sonnet 4.5...")
print(f"\nPrompt: {sonnet_prompt}")
print("\n" + "="*70)

if aws_bearer_token:
    try:
        response, error = call_bedrock_converse(
            sonnet_model_id, 
            sonnet_prompt, 
            max_tokens=850,
            temperature=0.7
        )
        
        if error:
            print(f"❌ Error: {error}")
        else:
            # Extract the text content from the response
            response_text = response['output']['message']['content'][0]['text']
            print("✅ Response:")
            print(response_text)
        
    except Exception as e:
        print(f"❌ Error: {e}")
        import traceback
        traceback.print_exc()
else:
    print("⚠️  Bearer token not found. Please set AWS_BEARER_TOKEN_BEDROCK or AWS_BEARER_TOKEN")
# Out:
# Testing Claude Sonnet 4.5...
#
# Prompt: Say 'Claude Sonnet 4.5 is working!' and explain what you're best at.
#
# ======================================================================
# ✅ Response:
# Claude Sonnet 4.5 is working!
#
# I'm best at:
#
# 🎯 **Deep analysis and reasoning** - I excel at breaking down complex problems, thinking through multi-step challenges, and providing nuanced insights across technical and creative domains.
#
# 📝 **Writing and communication** - Whether it's crafting clear explanations, creative content, professional documents, or adapting my tone to different audiences, I can help with diverse writing tasks.
#
# 💻 **Coding and technical work** - I'm strong at programming across multiple languages, debugging, explaining technical concepts, and helping with software development challenges.
#
# 🔍 **Research and synthesis** - I can help gather information, compare different perspectives, summarize complex topics, and connect ideas across disciplines.
#
# 🤝 **Collaborative problem-solving** - I work well as a thought partner, asking clarifying questions and iterating on solutions based on your feedback.
#
# What can I help you with today?

# %%
# Test Claude Haiku 4.5
haiku_prompt = "Say 'Claude Haiku 4.5 is working!' and explain what you're optimized for."

print("Testing Claude Haiku 4.5...")
print(f"\nPrompt: {haiku_prompt}")
print("\n" + "="*70)

if aws_bearer_token:
    try:
        response, error = call_bedrock_converse(
            haiku_model_id, 
            haiku_prompt, 
            max_tokens=300,
            temperature=1.0
        )
        
        if error:
            print(f"❌ Error: {error}")
        else:
            # Extract the text content from the response
            response_text = response['output']['message']['content'][0]['text']
            print("✅ Response:")
            print(response_text)
        
    except Exception as e:
        print(f"❌ Error: {e}")
        import traceback
        traceback.print_exc()
else:
    print("⚠️  Bearer token not found. Please set AWS_BEARER_TOKEN_BEDROCK or AWS_BEARER_TOKEN")
# Out:
# Testing Claude Haiku 4.5...
#
# Prompt: Say 'Claude Haiku 4.5 is working!' and explain what you're optimized for.
#
# ======================================================================
# ✅ Response:
# Claude Haiku 4.5 is working!
#
# I'm Claude, made by Anthropic. I should clarify that I'm Claude 3.5 Haiku (the latest version of Haiku that I'm aware of), not "4.5."
#
# I'm optimized for:
#
# - **Fast, efficient responses** - I'm designed to be quick while maintaining quality
# - **Helpful conversation** - I aim to be genuinely useful across a wide range of tasks
# - **Clear communication** - Breaking down complex topics into understandable explanations
# - **Coding and analysis** - Writing and debugging code, analyzing data, and technical problem-solving
# - **Creative tasks** - Writing, brainstorming, and generating ideas
# - **Reasoning** - Working through problems step-by-step and explaining my thinking
# - **Safety** - Being honest about limitations and declining harmful requests
#
# I try to be direct, accurate, and helpful while acknowledging uncertainty when appropriate.

# %%
# Coding task test with Sonnet 4.5
coding_prompt = """Write a LangGraph with Langchain function environmental planning agent that also uses Autogen, GCP RAG, and GCP Vertex AI, along with Autogen and LlamaIndex."""

print("Testing Sonnet 4.5 coding capabilities...")
print("\n" + "="*70)

if aws_bearer_token:
    try:
        response, error = call_bedrock_converse(
            sonnet_model_id, 
            coding_prompt, 
            max_tokens=1000, 
            temperature=0.2  # Lower temperature for code generation
        )
        
        if error:
            print(f"❌ Error: {error}")
        else:
            # Extract the text content from the response
            response_text = response['output']['message']['content'][0]['text']
            print("✅ Response:")
            print(response_text)
        
    except Exception as e:
        print(f"❌ Error: {e}")
        import traceback
        traceback.print_exc()
else:
    print("⚠️  Bearer token not found. Please set AWS_BEARER_TOKEN_BEDROCK or AWS_BEARER_TOKEN")
# Out:
# Testing Sonnet 4.5 coding capabilities...
#
# ======================================================================
# ✅ Response:
# # Environmental Planning Agent with LangGraph, LangChain, AutoGen, GCP RAG, and LlamaIndex
#
# I'll create a comprehensive environmental planning agent that integrates all these technologies.
#
# ```python
# # requirements.txt
# """
# langgraph>=0.0.40
# langchain>=0.1.0
# langchain-google-vertexai>=0.1.0
# langchain-google-community>=0.1.0
# pyautogen>=0.2.0
# llama-index>=0.9.0
# llama-index-vector-stores-vertexai>=0.1.0
# google-cloud-aiplatform>=1.38.0
# google-cloud-storage>=2.10.0
# """
#
# import os
# from typing import TypedDict, Annotated, Sequence, List, Dict, Any
# import operator
# from datetime import datetime
#
# # LangGraph and LangChain imports
# from langgraph.graph import StateGraph, END
# from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage
# from langchain_google_vertexai import ChatVertexAI, VertexAIEmbeddings
# from langchain.prompts import ChatPromptTemplate
# from langchain.tools import Tool
# from langchain.agents import AgentExecutor, create_openai_functions_agent
#
# # AutoGen imports
# import autogen
# from autogen import AssistantAgent, UserProxyAgent, GroupChat, GroupChatManager
#
# # LlamaIndex imports
# from llama_index.core import (
#     VectorStoreIndex,
#     Document,
#     ServiceContext,
#     StorageContext,
#     Settings
# )
# from llama_index.vector_stores.vertexai import VertexAIVectorStore
# from llama_index.embeddings.vertex import VertexAIEmbedding
# from llama_index.llms.vertex import Vertex
#
# # GCP imports
# from google.cloud import aiplatform
# from google.cloud import storage
# import vertexai
# from vertexai.language_models import TextEmbeddingModel
# from vertexai.preview.generative_models import GenerativeModel
#
# # Initialize GCP
# PROJECT_ID = os.getenv("GCP_PROJECT_ID", "your-project-id")
# LOCATION = os.getenv("GCP_LOCATION", "us-central1")
# BUCKET_NAME = os.getenv("GCS_BUCKET", "environmental-planning-data")
#
# vertexai.init(project=PROJECT_ID, location=LOCATION)
# aiplatform.init(project=PROJECT_ID, location=LOCATION)
#
#
# # ============================================================================
# # 1. STATE DEFINITION FOR LANGGRAPH
# # ============================================================================
#
# class EnvironmentalPlanningState(TypedDict):
#     """State for the environmental planning agent."""
#     messages: Annotated[Sequence[BaseMessage], operator.add]
#     project_name: str
#     location: str
#     environmental_data: Dict[str, Any]
#     impact_assessment: Dict[str, Any]
#     recommendations: List[str]
#     stakeholder_feedback: List[str]
#     compliance_status: Dict[str, bool]
#     next_action: str
#     iteration_count: int
#
#
# # ============================================================================
# # 2. GCP RAG SETUP WITH LLAMAINDEX
# # ============================================================================
#
# class GCPRAGSystem:
#     """RAG system using GCP Vertex AI and LlamaIndex."""
#
#     def __init__(self):
#         # Initialize Vertex AI embeddings
#         self.embedding_model = VertexAIEmbedding(
#             model_name="textembedding-gecko@003",
#             project=PROJECT_ID,
#             location=LOCATION
#         )
#
#         # Initialize Vertex AI LLM
#         self.llm = Vertex(
#             model="gemini-pro",
#             project=PROJECT_ID,
#             location=LOCATION,
#             temperature=0.7
#         )
#
#         # Configure LlamaIndex settings
#         Settings.llm = self.llm
#         Settings.embed_model = self.embedding_model
#         Settings.chunk_size = 512
#         Settings.chunk_overlap = 50
#
#         # Initialize Vector Store
